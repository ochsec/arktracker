# %%
import pandas as pd
import requests
import io

url = "https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_ISRAEL_INNOVATIVE_TECHNOLOGY_ETF_IZRL_HOLDINGS.csv"
r = requests.get(url)
data = r.content.decode('utf8')
df = pd.read_csv(io.StringIO(data))
df.dropna(how='any')
# Out:
#          date  fund                       company   ticker      cusip  \
# 0   12/4/2020  IZRL  ONE SOFTWARE TECHNOLOGIES LT      ONE    6987709
# 1   12/4/2020  IZRL      RADA ELECTRONIC INDS LTD     RADA  M81863124
# 2   12/4/2020  IZRL       TOWER SEMICONDUCTOR LTD     TSEM  M87915274
# 3   12/4/2020  IZRL   ITURAN LOCATION AND CONTROL     ITRN  M6158M104
# 4   12/4/2020  IZRL               GAMIDA CELL LTD     GMDA  M47364100
# 5   12/4/2020  IZRL      FIVERR INTERNATIONAL LTD     FVRR  M4R82T106
# 6   12/4/2020  IZRL      FATTAL HOLDINGS 1998 LTD     FTAL    BG1YKN5
# 7   12/4/2020  IZRL          CERAGON NETWORKS LTD     CRNT  M22013102
# 8   12/4/2020  IZRL  GILAT SATELLITE NETWORKS LTD     GILT  M51474118
# 9   12/4/2020  IZRL      DANEL (ADIR YEOSHUA) LTD     DANE    6253433
# 10  12/4/2020  IZRL     PARTNER COMMUNICATIONS CO     PTNR    6374420
# 11  12/4/2020  IZRL     TARO PHARMACEUTICAL INDUS     TARO  M8737E108
# ...
